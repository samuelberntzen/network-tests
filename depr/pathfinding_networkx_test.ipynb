# %%
place = "Oslo"

import json
import os
import geopandas as gpd


os.environ["USE_PYGEOS"] = "0"
os.environ["LD_LIBRARY_PATH"] = "/usr/lib/x86_64-linux-gnu/libstdc++.so.6"

# Specify the file paths
nodes_filepath = f"data/{place}_nodes.geojson"
edges_filepath = f"data/{place}_edges.geojson"

# Load GeoJSON files as GeoDataFrames
nodes_gdf = gpd.read_file(nodes_filepath)
edges_gdf = gpd.read_file(edges_filepath)
# Out:
# /home/samuel/Documents/GitHub/network-tests/venv/lib/python3.11/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /tmp/ipykernel_61070/1045735158.py:5: DeprecationWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas still uses PyGEOS by default. However, starting with version 0.14, the default will switch to Shapely. To force to use Shapely 2.0 now, you can either uninstall PyGEOS or set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# ...

# %%
nodes_gdf["x"] = nodes_gdf["geometry"].x
nodes_gdf["y"] = nodes_gdf["geometry"].y

# %%
edges_gdf
# Out:
#                 id            u            v      highway  \
# 0            17834   3441703623   3441700286  residential
# 1            17834   3441700286       647765  residential
# 2            17834       647765   8496457084  residential
# 3            17834   8496457084       106196  residential
# 4            17836       106168   1387801989     tertiary
# ...            ...          ...          ...          ...
# 147749  1201024125  11135753840  11135753841      footway
# 147750  1201024125  11135753841  11135753842      footway
# 147751  1201024127  11135753845  11135753846      footway
# 147752  1201024128  11135753843  11135753845      footway
# 147753  1201024129  11135753844   8486909953      footway
#
#                                   category  category_score  lit oneway  \
# 0                   Road without bike lane               6  yes    NaN
# 1                   Road without bike lane               6  yes    NaN
# ...

# %%
import osmnx as ox

G = ox.graph_from_gdfs(nodes_gdf, edges_gdf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import osmnx as ox
# ----> 2 G = ox.graph_from_gdfs(nodes_gdf, edges_gdf)
#
# File ~/Documents/GitHub/network-tests/venv/lib/python3.11/site-packages/osmnx/utils_graph.py:169, in graph_from_gdfs(gdf_nodes, gdf_edges, graph_attrs)
#     166 # add edges and their attributes to graph, but filter out null attribute
#     167 # values so that edges only get attributes with non-null values
#     168 attr_names = gdf_edges.columns.to_list()
# --> 169 for (u, v, k), attr_vals in zip(gdf_edges.index, gdf_edges.values):
#     170     data_all = zip(attr_names, attr_vals)
#     171     data = {name: val for name, val in data_all if isinstance(val, list) or pd.notnull(val)}
#
# TypeError: cannot unpack non-iterable int object
